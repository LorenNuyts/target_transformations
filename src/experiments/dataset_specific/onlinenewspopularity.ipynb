# %%
# %env DATA_DIR=/home/loren/Code/evaluation/data/datasets
# Out:
# env: DATA_DIR=/home/loren/Code/evaluation/data/datasets

# %%
from src.experiments.data import OnlineNewsPopularity
from ucimlrepo import fetch_ucirepo

# %% [markdown]
# # Load data

# %%
data = OnlineNewsPopularity()
data.load_dataset()
full_dataset = fetch_ucirepo(id=332)
X_full = full_dataset.data.original.drop(columns=['url', ' shares'])
y = full_dataset.data.targets.squeeze()
# Out:
# loading OnlineNewsPopularity h5 file

# %%
data.X.head()
# Out:
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0        0.476190          0.025844         0.000947           0.00096
# 1        0.333333          0.030092         0.000863           0.00096
# 2        0.333333          0.024900         0.000820           0.00096
# 3        0.333333          0.062662         0.000719           0.00096
# 4        0.523810          0.126505         0.000593           0.00096
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.001254   0.013158        0.017241  0.007812         0.0
# 1                  0.001218   0.009868        0.008621  0.007812         0.0
# 2                  0.001021   0.009868        0.008621  0.007812         0.0
# 3                  0.001024   0.029605        0.000000  0.007812         0.0
# 4                  0.000832   0.062500        0.163793  0.156250         0.0
#
# ...

# %%
X_full.head()
# Out:
#    timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0      731.0            12.0             219.0         0.663594
# 1      731.0             9.0             255.0         0.604743
# 2      731.0             9.0             211.0         0.575130
# 3      731.0             9.0             531.0         0.503788
# 4      731.0            13.0            1072.0         0.415646
#
#    n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 0               1.0                  0.815385        4.0             2.0
# 1               1.0                  0.791946        3.0             1.0
# 2               1.0                  0.663866        3.0             1.0
# 3               1.0                  0.665635        9.0             0.0
# 4               1.0                  0.540890       19.0            19.0
#
#    num_imgs  num_videos  ...  avg_positive_polarity  min_positive_polarity  \
# ...

# %% [markdown]
# # Is target correlated with timedelta?

# %%
# Correlation with casual users
X_full[' timedelta'].corr(y)
# Out:
# 0.008662287711262545

# %% [markdown]
# Not really it seems.

# %%
new_y = y/X_full[' timedelta']
X_full[' timedelta'].corr(new_y)
# Out:
# -0.19481819181733867

# %% [markdown]
# Normalizing with it even gives a higher absolute correlation!
