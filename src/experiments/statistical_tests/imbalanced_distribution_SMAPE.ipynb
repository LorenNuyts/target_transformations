# %%
import os

os.environ['DATA_DIR'] = "/home/loren/Code/evaluation/data/datasets"

# %%
from multiple_classifiers import friedman_test, nemenyi_friedman_test, bonferroni_dunn_test
import pandas as pd

from src.experiments.print_results import get_results
from src.experiments.data import datasets, imbalanced_distribution_datasets
from src.experiments.print_results import all_metrics
from src.experiments.utils import Keys, get_clf_full_name

# %% [markdown]
# # Import the results

# %%
from src.experiments.imbalanced_distribution import DEFAULT_CLFS

datasets_ = list(imbalanced_distribution_datasets.keys())
metric = Keys.average_smape
experiment_ = 'imbalanced_distribution'
suffix_ = ""
from_pkl_ = False
clfs = DEFAULT_CLFS
feature_transformer_name = None
incl_transformers = [None, Keys.transformer_quantile_normal, Keys.transformer_quantile_uniform,
                             Keys.transformer_powertransformer, Keys.transformer_lntransformer]
column_order = [get_clf_full_name(clf.name, transformer, feature_transformer_name).replace(' ', '')
                                              for clf in clfs for transformer in incl_transformers]

# %%
all_results = {}
for clf in clfs:
    column_order = [get_clf_full_name(clf.name, transformer, feature_transformer_name).replace(' ', '') for transformer in incl_transformers]
    all_results[clf.name] = get_results(datasets_, metric.replace(' ', ''), experiment_,
                                    # present_substring=f"__f_{feature_transformer_name}".replace(' ', ''),
                                    # absent_substring='__f_',
                                    suffix=suffix_, from_text=not from_pkl_,
                                    column_order=column_order)

# %% [markdown]
# # Run the statistical tests

# %%
def average_improvement(x, lower_is_better=False):
    improvements = []
    baseline = x[[x.columns[0]]].values
    for c in x.columns[1:]:
        if lower_is_better:
            improvements_column = (baseline - x[[c]].values) / baseline * 100
        else:
            improvements_column = (x[[c]].values - baseline)
        improvements.append(improvements_column.mean())
    return pd.DataFrame(improvements, index=list(x.columns[1:]), columns=[x.columns[0]])

# %%
def run_stats(to_compare, control: str, lower_is_better=True):
    from classifier_comparisons import BlockDesign
    # pd.set_option('display.max_rows', None)
    # pd.set_option('display.max_columns', None)

    block_design = BlockDesign(to_compare, threshold=0.001, precision=3, higher_is_better=(not lower_is_better))
    test_results = friedman_test(block_design, alpha=0.05)
    print("test results: \n", test_results)
    print("##############################################")
    average_ranks = block_design.to_ranks()
    print("average ranks: \n", average_ranks)
    print("##############################################")
    wins = BlockDesign(to_compare).to_wins_ties_losses()
    print("wins ties losses: \n", wins)
    print("##############################################")
    p_values, sign_diffs = nemenyi_friedman_test(block_design, alpha=0.05)
    print("p values: ", p_values.data)
    print("sign diffs", sign_diffs.data)
    print("##############################################")

    p_values, sign_diffs = bonferroni_dunn_test(block_design, alpha=0.05, control=control)
    print("p values: ", p_values.data)
    print("sign diffs", sign_diffs.data)

    print("##############################################")
    print("average improvement compared with the first column: \n", average_improvement(to_compare, lower_is_better))

# %% [markdown]
# ## Lasso

# %%
clf = "LassoTuned"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729           5.76  0.217803
# Iman Davenport  0.05       2.633532       1.514019  0.218708
#
#                significant? (test stat > crit value)
# Friedman test                                  False
# Iman Davenport                                 False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                  average rank  standard deviation
# LassoTuned                               3.9            1.577973
# LassoTuned__Quantile(normal)             2.3            1.100000
# LassoTuned__Quantile(uniform)            3.2            1.077033
# LassoTuned__PowerTransformer             2.9            1.135782
# LassoTuned__LogTransformer(ln)           2.7            1.552417
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                 LassoTuned LassoTuned__Quantile(normal)  \
# LassoTuned                         0-10-0                        8-0-2
# LassoTuned__Quantile(normal)        2-0-8                       0-10-0
# LassoTuned__Quantile(uniform)       4-0-6                        7-0-3
# LassoTuned__PowerTransformer        3-0-7                        6-0-4
# LassoTuned__LogTransformer(ln)      2-0-8                        6-0-4
#
#                                LassoTuned__Quantile(uniform)  \
# LassoTuned                                             6-0-4
# LassoTuned__Quantile(normal)                           3-0-7
# LassoTuned__Quantile(uniform)                         0-10-0
# LassoTuned__PowerTransformer                           4-0-6
# LassoTuned__LogTransformer(ln)                         5-0-5
#
#                                LassoTuned__PowerTransformer  \
# LassoTuned                                            7-0-3
# LassoTuned__Quantile(normal)                          4-0-6
# LassoTuned__Quantile(uniform)                         6-0-4
# LassoTuned__PowerTransformer                         0-10-0
# LassoTuned__LogTransformer(ln)                        4-0-6
#
#                                LassoTuned__LogTransformer(ln)
# LassoTuned                                              8-0-2
# LassoTuned__Quantile(normal)                            4-0-6
# LassoTuned__Quantile(uniform)                           5-0-5
# LassoTuned__PowerTransformer                            6-0-4
# LassoTuned__LogTransformer(ln)                         0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                  LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned                        1.000000                      0.157170
# LassoTuned__Quantile(normal)      0.157170                      1.000000
# LassoTuned__Quantile(uniform)     0.843526                      0.683006
# LassoTuned__PowerTransformer      0.602746                      0.900000
# LassoTuned__LogTransformer(ln)    0.437421                      0.900000
#
#                                 LassoTuned__Quantile(uniform)  \
# LassoTuned                                           0.843526
# LassoTuned__Quantile(normal)                         0.683006
# LassoTuned__Quantile(uniform)                        1.000000
# LassoTuned__PowerTransformer                         0.900000
# LassoTuned__LogTransformer(ln)                       0.900000
#
#                                 LassoTuned__PowerTransformer  \
# LassoTuned                                          0.602746
# LassoTuned__Quantile(normal)                        0.900000
# LassoTuned__Quantile(uniform)                       0.900000
# LassoTuned__PowerTransformer                        1.000000
# LassoTuned__LogTransformer(ln)                      0.900000
#
#                                 LassoTuned__LogTransformer(ln)
# LassoTuned                                            0.437421
# LassoTuned__Quantile(normal)                          0.900000
# LassoTuned__Quantile(uniform)                         0.900000
# LassoTuned__PowerTransformer                          0.900000
# LassoTuned__LogTransformer(ln)                        1.000000
# sign diffs                                 LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned                           False                         False
# LassoTuned__Quantile(normal)         False                         False
# LassoTuned__Quantile(uniform)        False                         False
# LassoTuned__PowerTransformer         False                         False
# LassoTuned__LogTransformer(ln)       False                         False
#
#                                 LassoTuned__Quantile(uniform)  \
# LassoTuned                                              False
# LassoTuned__Quantile(normal)                            False
# LassoTuned__Quantile(uniform)                           False
# LassoTuned__PowerTransformer                            False
# LassoTuned__LogTransformer(ln)                          False
#
#                                 LassoTuned__PowerTransformer  \
# LassoTuned                                             False
# LassoTuned__Quantile(normal)                           False
# LassoTuned__Quantile(uniform)                          False
# LassoTuned__PowerTransformer                           False
# LassoTuned__LogTransformer(ln)                         False
#
#                                 LassoTuned__LogTransformer(ln)
# LassoTuned                                               False
# LassoTuned__Quantile(normal)                             False
# LassoTuned__Quantile(uniform)                            False
# LassoTuned__PowerTransformer                             False
# LassoTuned__LogTransformer(ln)                           False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:              LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned         1.0                      0.023652
#
#             LassoTuned__Quantile(uniform)  LassoTuned__PowerTransformer  \
# LassoTuned                       0.322199                      0.157299
#
#             LassoTuned__LogTransformer(ln)
# LassoTuned                        0.089686
# sign diffs             LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned       False                         False
#
#             LassoTuned__Quantile(uniform)  LassoTuned__PowerTransformer  \
# LassoTuned                          False                         False
#
#             LassoTuned__LogTransformer(ln)
# LassoTuned                           False
# ##############################################
# average improvement compared with the first column:
#                                  LassoTuned
# LassoTuned__Quantile(normal)     11.730689
# LassoTuned__Quantile(uniform)     9.498311
# LassoTuned__PowerTransformer     -6.484435
# LassoTuned__LogTransformer(ln)   10.053633

# %% [markdown]
# ## Ridge

# %%
clf = "RidgeRegressionTuned"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729           8.26  0.082505
# Iman Davenport  0.05       2.633532       2.342155  0.073369
#
#                significant? (test stat > crit value)
# Friedman test                                  False
# Iman Davenport                                 False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                            average rank  standard deviation
# RidgeRegressionTuned                              4.10            1.374773
# RidgeRegressionTuned__Quantile(normal)            2.20            1.077033
# RidgeRegressionTuned__Quantile(uniform)           3.10            1.374773
# RidgeRegressionTuned__PowerTransformer            2.55            1.059481
# RidgeRegressionTuned__LogTransformer(ln)          3.05            1.350000
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                           RidgeRegressionTuned  \
# RidgeRegressionTuned                                   0-10-0
# RidgeRegressionTuned__Quantile(normal)                  1-0-9
# RidgeRegressionTuned__Quantile(uniform)                 4-0-6
# RidgeRegressionTuned__PowerTransformer                  2-0-8
# RidgeRegressionTuned__LogTransformer(ln)                2-0-8
#
#                                          RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                                      9-0-1
# RidgeRegressionTuned__Quantile(normal)                                   0-10-0
# RidgeRegressionTuned__Quantile(uniform)                                   7-0-3
# RidgeRegressionTuned__PowerTransformer                                    6-0-4
# RidgeRegressionTuned__LogTransformer(ln)                                  6-0-4
#
#                                          RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                                       6-0-4
# RidgeRegressionTuned__Quantile(normal)                                     3-0-7
# RidgeRegressionTuned__Quantile(uniform)                                   0-10-0
# RidgeRegressionTuned__PowerTransformer                                     4-0-6
# RidgeRegressionTuned__LogTransformer(ln)                                   6-0-4
#
#                                          RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                                      8-0-2
# RidgeRegressionTuned__Quantile(normal)                                    4-0-6
# RidgeRegressionTuned__Quantile(uniform)                                   6-0-4
# RidgeRegressionTuned__PowerTransformer                                   0-10-0
# RidgeRegressionTuned__LogTransformer(ln)                                  7-0-3
#
#                                          RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                                        8-0-2
# RidgeRegressionTuned__Quantile(normal)                                      4-0-6
# RidgeRegressionTuned__Quantile(uniform)                                     4-0-6
# RidgeRegressionTuned__PowerTransformer                                      3-0-7
# RidgeRegressionTuned__LogTransformer(ln)                                   0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                            RidgeRegressionTuned  \
# RidgeRegressionTuned                                  1.000000
# RidgeRegressionTuned__Quantile(normal)                0.055906
# RidgeRegressionTuned__Quantile(uniform)               0.602746
# RidgeRegressionTuned__PowerTransformer                0.182487
# RidgeRegressionTuned__LogTransformer(ln)              0.562614
#
#                                           RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                                    0.055906
# RidgeRegressionTuned__Quantile(normal)                                  1.000000
# RidgeRegressionTuned__Quantile(uniform)                                 0.683006
# RidgeRegressionTuned__PowerTransformer                                  0.900000
# RidgeRegressionTuned__LogTransformer(ln)                                0.723137
#
#                                           RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                                     0.602746
# RidgeRegressionTuned__Quantile(normal)                                   0.683006
# RidgeRegressionTuned__Quantile(uniform)                                  1.000000
# RidgeRegressionTuned__PowerTransformer                                   0.900000
# RidgeRegressionTuned__LogTransformer(ln)                                 0.900000
#
#                                           RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                                    0.182487
# RidgeRegressionTuned__Quantile(normal)                                  0.900000
# RidgeRegressionTuned__Quantile(uniform)                                 0.900000
# RidgeRegressionTuned__PowerTransformer                                  1.000000
# RidgeRegressionTuned__LogTransformer(ln)                                0.900000
#
#                                           RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                                      0.562614
# RidgeRegressionTuned__Quantile(normal)                                    0.723137
# RidgeRegressionTuned__Quantile(uniform)                                   0.900000
# RidgeRegressionTuned__PowerTransformer                                    0.900000
# RidgeRegressionTuned__LogTransformer(ln)                                  1.000000
# sign diffs                                           RidgeRegressionTuned  \
# RidgeRegressionTuned                                     False
# RidgeRegressionTuned__Quantile(normal)                   False
# RidgeRegressionTuned__Quantile(uniform)                  False
# RidgeRegressionTuned__PowerTransformer                   False
# RidgeRegressionTuned__LogTransformer(ln)                 False
#
#                                           RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                                       False
# RidgeRegressionTuned__Quantile(normal)                                     False
# RidgeRegressionTuned__Quantile(uniform)                                    False
# RidgeRegressionTuned__PowerTransformer                                     False
# RidgeRegressionTuned__LogTransformer(ln)                                   False
#
#                                           RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                                        False
# RidgeRegressionTuned__Quantile(normal)                                      False
# RidgeRegressionTuned__Quantile(uniform)                                     False
# RidgeRegressionTuned__PowerTransformer                                      False
# RidgeRegressionTuned__LogTransformer(ln)                                    False
#
#                                           RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                                       False
# RidgeRegressionTuned__Quantile(normal)                                     False
# RidgeRegressionTuned__Quantile(uniform)                                    False
# RidgeRegressionTuned__PowerTransformer                                     False
# RidgeRegressionTuned__LogTransformer(ln)                                   False
#
#                                           RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                                         False
# RidgeRegressionTuned__Quantile(normal)                                       False
# RidgeRegressionTuned__Quantile(uniform)                                      False
# RidgeRegressionTuned__PowerTransformer                                       False
# RidgeRegressionTuned__LogTransformer(ln)                                     False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:                        RidgeRegressionTuned  \
# RidgeRegressionTuned                   1.0
#
#                       RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                 0.00721
#
#                       RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                 0.157299
#
#                       RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                0.028377
#
#                       RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                  0.137564
# sign diffs                       RidgeRegressionTuned  \
# RidgeRegressionTuned                 False
#
#                       RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                    True
#
#                       RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                    False
#
#                       RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                   False
#
#                       RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                     False
# ##############################################
# average improvement compared with the first column:
#                                            RidgeRegressionTuned
# RidgeRegressionTuned__Quantile(normal)               11.230673
# RidgeRegressionTuned__Quantile(uniform)               9.717619
# RidgeRegressionTuned__PowerTransformer               11.853809
# RidgeRegressionTuned__LogTransformer(ln)              9.895689

# %% [markdown]
# ## Gradient Boosted Trees Regressor

# %%
clf = "GradientBoostingRegressorWrapper"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729          12.56  0.013638
# Iman Davenport  0.05       2.633532       4.119534   0.00753
#
#                significant? (test stat > crit value)
# Friedman test                                   True
# Iman Davenport                                  True
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                                      average rank  \
# GradientBoostingRegressorWrapper                             3.5
# GradientBoostingRegressorWrapper__Quantile(normal)           4.1
# GradientBoostingRegressorWrapper__Quantile(unif...           3.2
# GradientBoostingRegressorWrapper__PowerTransformer           2.2
# GradientBoostingRegressorWrapper__LogTransforme...           2.0
#
#                                                     standard deviation
# GradientBoostingRegressorWrapper                              1.118034
# GradientBoostingRegressorWrapper__Quantile(normal)            1.300000
# GradientBoostingRegressorWrapper__Quantile(unif...            1.326650
# GradientBoostingRegressorWrapper__PowerTransformer            1.077033
# GradientBoostingRegressorWrapper__LogTransforme...            1.000000
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                                     GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                                             0-10-0
# GradientBoostingRegressorWrapper__Quantile(normal)                            8-0-2
# GradientBoostingRegressorWrapper__Quantile(unif...                            5-0-5
# GradientBoostingRegressorWrapper__PowerTransformer                            1-0-9
# GradientBoostingRegressorWrapper__LogTransforme...                            1-0-9
#
#                                                    GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                                                2-0-8
# GradientBoostingRegressorWrapper__Quantile(normal)                                             0-10-0
# GradientBoostingRegressorWrapper__Quantile(unif...                                              4-0-6
# GradientBoostingRegressorWrapper__PowerTransformer                                              2-0-8
# GradientBoostingRegressorWrapper__LogTransforme...                                              1-0-9
#
#                                                    GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                                                5-0-5
# GradientBoostingRegressorWrapper__Quantile(normal)                                              6-0-4
# GradientBoostingRegressorWrapper__Quantile(unif...                                             0-10-0
# GradientBoostingRegressorWrapper__PowerTransformer                                              4-0-6
# GradientBoostingRegressorWrapper__LogTransforme...                                              3-0-7
#
#                                                    GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                                                9-0-1
# GradientBoostingRegressorWrapper__Quantile(normal)                                              8-0-2
# GradientBoostingRegressorWrapper__Quantile(unif...                                              6-0-4
# GradientBoostingRegressorWrapper__PowerTransformer                                             0-10-0
# GradientBoostingRegressorWrapper__LogTransforme...                                              5-0-5
#
#                                                    GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                                                9-0-1
# GradientBoostingRegressorWrapper__Quantile(normal)                                              9-0-1
# GradientBoostingRegressorWrapper__Quantile(unif...                                              7-0-3
# GradientBoostingRegressorWrapper__PowerTransformer                                              5-0-5
# GradientBoostingRegressorWrapper__LogTransforme...                                             0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                                      GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                                            1.000000
# GradientBoostingRegressorWrapper__Quantile(normal)                          0.900000
# GradientBoostingRegressorWrapper__Quantile(unif...                          0.900000
# GradientBoostingRegressorWrapper__PowerTransformer                          0.351727
# GradientBoostingRegressorWrapper__LogTransforme...                          0.210897
#
#                                                     GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                                             0.900000
# GradientBoostingRegressorWrapper__Quantile(normal)                                           1.000000
# GradientBoostingRegressorWrapper__Quantile(unif...                                           0.683006
# GradientBoostingRegressorWrapper__PowerTransformer                                           0.055906
# GradientBoostingRegressorWrapper__LogTransforme...                                           0.024841
#
#                                                     GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                                             0.900000
# GradientBoostingRegressorWrapper__Quantile(normal)                                           0.683006
# GradientBoostingRegressorWrapper__Quantile(unif...                                           1.000000
# GradientBoostingRegressorWrapper__PowerTransformer                                           0.602746
# GradientBoostingRegressorWrapper__LogTransforme...                                           0.437421
#
#                                                     GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                                             0.351727
# GradientBoostingRegressorWrapper__Quantile(normal)                                           0.055906
# GradientBoostingRegressorWrapper__Quantile(unif...                                           0.602746
# GradientBoostingRegressorWrapper__PowerTransformer                                           1.000000
# GradientBoostingRegressorWrapper__LogTransforme...                                           0.900000
#
#                                                     GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                                             0.210897
# GradientBoostingRegressorWrapper__Quantile(normal)                                           0.024841
# GradientBoostingRegressorWrapper__Quantile(unif...                                           0.437421
# GradientBoostingRegressorWrapper__PowerTransformer                                           0.900000
# GradientBoostingRegressorWrapper__LogTransforme...                                           1.000000
# sign diffs                                                     GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                                               False
# GradientBoostingRegressorWrapper__Quantile(normal)                             False
# GradientBoostingRegressorWrapper__Quantile(unif...                             False
# GradientBoostingRegressorWrapper__PowerTransformer                             False
# GradientBoostingRegressorWrapper__LogTransforme...                             False
#
#                                                     GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                               True
#
#                                                     GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
#
#                                                     GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
#
#                                                     GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                               True
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:                                    GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                               1.0
#
#                                   GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                           0.396144
#
#                                   GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                           0.671373
#
#                                   GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                           0.065992
#
#                                   GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                           0.033895
# sign diffs                                   GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                             False
#
#                                   GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                              False
#
#                                   GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                              False
#
#                                   GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                              False
#
#                                   GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                              False
# ##############################################
# average improvement compared with the first column:
#                                                      GradientBoostingRegressorWrapper
# GradientBoostingRegressorWrapper__Quantile(normal)                         -5.614322
# GradientBoostingRegressorWrapper__Quantile(unif...                          1.190744
# GradientBoostingRegressorWrapper__PowerTransformer                        -16.317150
# GradientBoostingRegressorWrapper__LogTransforme...                          7.584347

# %% [markdown]
# ## SVR

# %%
clf = "SupportVectorRegressorWrapper"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729          22.16  0.000186
# Iman Davenport  0.05       2.633532      11.179372  0.000005
#
#                significant? (test stat > crit value)
# Friedman test                                   True
# Iman Davenport                                  True
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                                     average rank  \
# SupportVectorRegressorWrapper                               4.6
# SupportVectorRegressorWrapper__Quantile(normal)             1.4
# SupportVectorRegressorWrapper__Quantile(uniform)            3.5
# SupportVectorRegressorWrapper__PowerTransformer             2.6
# SupportVectorRegressorWrapper__LogTransformer(ln)           2.9
#
#                                                    standard deviation
# SupportVectorRegressorWrapper                                0.916515
# SupportVectorRegressorWrapper__Quantile(normal)              0.663325
# SupportVectorRegressorWrapper__Quantile(uniform)             0.921954
# SupportVectorRegressorWrapper__PowerTransformer              0.800000
# SupportVectorRegressorWrapper__LogTransformer(ln)            1.300000
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                                    SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                                            0-10-0
# SupportVectorRegressorWrapper__Quantile(normal)                          0-0-10
# SupportVectorRegressorWrapper__Quantile(uniform)                          2-0-8
# SupportVectorRegressorWrapper__PowerTransformer                           1-0-9
# SupportVectorRegressorWrapper__LogTransformer(ln)                         1-0-9
#
#                                                   SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                                              10-0-0
# SupportVectorRegressorWrapper__Quantile(normal)                                            0-10-0
# SupportVectorRegressorWrapper__Quantile(uniform)                                           10-0-0
# SupportVectorRegressorWrapper__PowerTransformer                                             9-0-1
# SupportVectorRegressorWrapper__LogTransformer(ln)                                           7-0-3
#
#                                                   SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                                                8-0-2
# SupportVectorRegressorWrapper__Quantile(normal)                                             0-0-10
# SupportVectorRegressorWrapper__Quantile(uniform)                                            0-10-0
# SupportVectorRegressorWrapper__PowerTransformer                                              3-0-7
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            4-0-6
#
#                                                   SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                                               9-0-1
# SupportVectorRegressorWrapper__Quantile(normal)                                             1-0-9
# SupportVectorRegressorWrapper__Quantile(uniform)                                            7-0-3
# SupportVectorRegressorWrapper__PowerTransformer                                            0-10-0
# SupportVectorRegressorWrapper__LogTransformer(ln)                                           7-0-3
#
#                                                   SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                                                 9-0-1
# SupportVectorRegressorWrapper__Quantile(normal)                                               3-0-7
# SupportVectorRegressorWrapper__Quantile(uniform)                                              6-0-4
# SupportVectorRegressorWrapper__PowerTransformer                                               3-0-7
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                                     SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                                           1.000000
# SupportVectorRegressorWrapper__Quantile(normal)                         0.001000
# SupportVectorRegressorWrapper__Quantile(uniform)                        0.522486
# SupportVectorRegressorWrapper__PowerTransformer                         0.037722
# SupportVectorRegressorWrapper__LogTransformer(ln)                       0.114265
#
#                                                    SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                                             0.001000
# SupportVectorRegressorWrapper__Quantile(normal)                                           1.000000
# SupportVectorRegressorWrapper__Quantile(uniform)                                          0.024841
# SupportVectorRegressorWrapper__PowerTransformer                                           0.437421
# SupportVectorRegressorWrapper__LogTransformer(ln)                                         0.210897
#
#                                                    SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                                              0.522486
# SupportVectorRegressorWrapper__Quantile(normal)                                            0.024841
# SupportVectorRegressorWrapper__Quantile(uniform)                                           1.000000
# SupportVectorRegressorWrapper__PowerTransformer                                            0.683006
# SupportVectorRegressorWrapper__LogTransformer(ln)                                          0.900000
#
#                                                    SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                                             0.037722
# SupportVectorRegressorWrapper__Quantile(normal)                                           0.437421
# SupportVectorRegressorWrapper__Quantile(uniform)                                          0.683006
# SupportVectorRegressorWrapper__PowerTransformer                                           1.000000
# SupportVectorRegressorWrapper__LogTransformer(ln)                                         0.900000
#
#                                                    SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                                               0.114265
# SupportVectorRegressorWrapper__Quantile(normal)                                             0.210897
# SupportVectorRegressorWrapper__Quantile(uniform)                                            0.900000
# SupportVectorRegressorWrapper__PowerTransformer                                             0.900000
# SupportVectorRegressorWrapper__LogTransformer(ln)                                           1.000000
# sign diffs                                                    SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                                              False
# SupportVectorRegressorWrapper__Quantile(normal)                             True
# SupportVectorRegressorWrapper__Quantile(uniform)                           False
# SupportVectorRegressorWrapper__PowerTransformer                             True
# SupportVectorRegressorWrapper__LogTransformer(ln)                          False
#
#                                                    SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                                                 True
# SupportVectorRegressorWrapper__Quantile(normal)                                              False
# SupportVectorRegressorWrapper__Quantile(uniform)                                              True
# SupportVectorRegressorWrapper__PowerTransformer                                              False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            False
#
#                                                    SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                                                 False
# SupportVectorRegressorWrapper__Quantile(normal)                                                True
# SupportVectorRegressorWrapper__Quantile(uniform)                                              False
# SupportVectorRegressorWrapper__PowerTransformer                                               False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                             False
#
#                                                    SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                                                 True
# SupportVectorRegressorWrapper__Quantile(normal)                                              False
# SupportVectorRegressorWrapper__Quantile(uniform)                                             False
# SupportVectorRegressorWrapper__PowerTransformer                                              False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            False
#
#                                                    SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                                                  False
# SupportVectorRegressorWrapper__Quantile(normal)                                                False
# SupportVectorRegressorWrapper__Quantile(uniform)                                               False
# SupportVectorRegressorWrapper__PowerTransformer                                                False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                              False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:                                 SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                            1.0
#
#                                SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                         0.000006
#
#                                SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                          0.119795
#
#                                SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                         0.004678
#
#                                SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                            0.01621
# sign diffs                                SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                          False
#
#                                SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                             True
#
#                                SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                             False
#
#                                SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                             True
#
#                                SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                              False
# ##############################################
# average improvement compared with the first column:
#                                                     SupportVectorRegressorWrapper
# SupportVectorRegressorWrapper__Quantile(normal)                        16.681992
# SupportVectorRegressorWrapper__Quantile(uniform)                        8.829550
# SupportVectorRegressorWrapper__PowerTransformer                        -6.270399
# SupportVectorRegressorWrapper__LogTransformer(ln)                     -24.030755
