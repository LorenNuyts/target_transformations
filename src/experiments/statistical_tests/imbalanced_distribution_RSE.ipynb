# %%
import os

os.environ['DATA_DIR'] = "/home/loren/Code/evaluation/data/datasets"

# %%
from multiple_classifiers import friedman_test, nemenyi_friedman_test, bonferroni_dunn_test
import pandas as pd

from src.experiments.print_results import get_results
from src.experiments.data import datasets, imbalanced_distribution_datasets
from src.experiments.print_results import all_metrics
from src.experiments.utils import Keys, get_clf_full_name

# %% [markdown]
# # Import the results

# %%
from src.experiments.imbalanced_distribution import DEFAULT_CLFS

datasets_ = list(imbalanced_distribution_datasets.keys())
metric = Keys.average_rse
experiment_ = 'imbalanced_distribution'
suffix_ = ""
from_pkl_ = False
clfs = DEFAULT_CLFS
feature_transformer_name = None
incl_transformers = [None, Keys.transformer_quantile_normal, Keys.transformer_quantile_uniform,
                             Keys.transformer_powertransformer, Keys.transformer_lntransformer]
column_order = [get_clf_full_name(clf.name, transformer, feature_transformer_name).replace(' ', '')
                                              for clf in clfs for transformer in incl_transformers]

# %%
all_results = {}
for clf in clfs:
    column_order = [get_clf_full_name(clf.name, transformer, feature_transformer_name).replace(' ', '') for transformer in incl_transformers]
    all_results[clf.name] = get_results(datasets_, metric.replace(' ', ''), experiment_,
                                    # present_substring=f"__f_{feature_transformer_name}".replace(' ', ''),
                                    # absent_substring='__f_',
                                    suffix=suffix_, from_text=not from_pkl_,
                                    column_order=column_order)

# %% [markdown]
# # Run the statistical tests

# %%
def average_improvement(x, lower_is_better=False):
    improvements = []
    baseline = x[[x.columns[0]]].values
    for c in x.columns[1:]:
        if lower_is_better:
            improvements_column = (baseline - x[[c]].values) / baseline * 100
        else:
            improvements_column = (x[[c]].values - baseline)
        improvements.append(improvements_column.mean())
    return pd.DataFrame(improvements, index=list(x.columns[1:]), columns=[x.columns[0]])

# %%
def run_stats(to_compare, control: str, lower_is_better=True):
    from classifier_comparisons import BlockDesign
    # pd.set_option('display.max_rows', None)
    # pd.set_option('display.max_columns', None)

    block_design = BlockDesign(to_compare, threshold=0.001, precision=3, higher_is_better=(not lower_is_better))
    test_results = friedman_test(block_design, alpha=0.05)
    print("test results: \n", test_results)
    print("##############################################")
    average_ranks = block_design.to_ranks()
    print("average ranks: \n", average_ranks)
    print("##############################################")
    wins = BlockDesign(to_compare).to_wins_ties_losses()
    print("wins ties losses: \n", wins)
    print("##############################################")
    p_values, sign_diffs = nemenyi_friedman_test(block_design, alpha=0.05)
    print("p values: ", p_values.data)
    print("sign diffs", sign_diffs.data)
    print("##############################################")

    p_values, sign_diffs = bonferroni_dunn_test(block_design, alpha=0.05, control=control)
    print("p values: ", p_values.data)
    print("sign diffs", sign_diffs.data)

    print("##############################################")
    print("average improvement compared with the first column: \n", average_improvement(to_compare, lower_is_better))

# %% [markdown]
# ## Lasso

# %%
clf = "LassoTuned"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729          16.96  0.001968
# Iman Davenport  0.05       2.633532          6.625   0.00042
#
#                significant? (test stat > crit value)
# Friedman test                                   True
# Iman Davenport                                  True
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                  average rank  standard deviation
# LassoTuned                              4.25            0.602080
# LassoTuned__Quantile(normal)            1.50            0.500000
# LassoTuned__Quantile(uniform)           3.55            1.709532
# LassoTuned__PowerTransformer            3.05            0.722842
# LassoTuned__LogTransformer(ln)          2.65            1.265899
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                 LassoTuned LassoTuned__Quantile(normal)  \
# LassoTuned                         0-10-0                       10-0-0
# LassoTuned__Quantile(normal)       0-0-10                       0-10-0
# LassoTuned__Quantile(uniform)       5-1-4                        7-1-2
# LassoTuned__PowerTransformer        1-0-9                       10-0-0
# LassoTuned__LogTransformer(ln)      1-1-8                        8-0-2
#
#                                LassoTuned__Quantile(uniform)  \
# LassoTuned                                             4-1-5
# LassoTuned__Quantile(normal)                           2-1-7
# LassoTuned__Quantile(uniform)                         0-10-0
# LassoTuned__PowerTransformer                           4-0-6
# LassoTuned__LogTransformer(ln)                         3-0-7
#
#                                LassoTuned__PowerTransformer  \
# LassoTuned                                            9-0-1
# LassoTuned__Quantile(normal)                         0-0-10
# LassoTuned__Quantile(uniform)                         6-0-4
# LassoTuned__PowerTransformer                         0-10-0
# LassoTuned__LogTransformer(ln)                        3-2-5
#
#                                LassoTuned__LogTransformer(ln)
# LassoTuned                                              8-1-1
# LassoTuned__Quantile(normal)                            2-0-8
# LassoTuned__Quantile(uniform)                           7-0-3
# LassoTuned__PowerTransformer                            5-2-3
# LassoTuned__LogTransformer(ln)                         0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                  LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned                        1.000000                      0.001000
# LassoTuned__Quantile(normal)      0.001000                      1.000000
# LassoTuned__Quantile(uniform)     0.843526                      0.030700
# LassoTuned__PowerTransformer      0.437421                      0.182487
# LassoTuned__LogTransformer(ln)    0.157170                      0.481073
#
#                                 LassoTuned__Quantile(uniform)  \
# LassoTuned                                           0.843526
# LassoTuned__Quantile(normal)                         0.030700
# LassoTuned__Quantile(uniform)                        1.000000
# LassoTuned__PowerTransformer                         0.900000
# LassoTuned__LogTransformer(ln)                       0.683006
#
#                                 LassoTuned__PowerTransformer  \
# LassoTuned                                          0.437421
# LassoTuned__Quantile(normal)                        0.182487
# LassoTuned__Quantile(uniform)                       0.900000
# LassoTuned__PowerTransformer                        1.000000
# LassoTuned__LogTransformer(ln)                      0.900000
#
#                                 LassoTuned__LogTransformer(ln)
# LassoTuned                                            0.157170
# LassoTuned__Quantile(normal)                          0.481073
# LassoTuned__Quantile(uniform)                         0.683006
# LassoTuned__PowerTransformer                          0.900000
# LassoTuned__LogTransformer(ln)                        1.000000
# sign diffs                                 LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned                           False                          True
# LassoTuned__Quantile(normal)          True                         False
# LassoTuned__Quantile(uniform)        False                          True
# LassoTuned__PowerTransformer         False                         False
# LassoTuned__LogTransformer(ln)       False                         False
#
#                                 LassoTuned__Quantile(uniform)  \
# LassoTuned                                              False
# LassoTuned__Quantile(normal)                             True
# LassoTuned__Quantile(uniform)                           False
# LassoTuned__PowerTransformer                            False
# LassoTuned__LogTransformer(ln)                          False
#
#                                 LassoTuned__PowerTransformer  \
# LassoTuned                                             False
# LassoTuned__Quantile(normal)                           False
# LassoTuned__Quantile(uniform)                          False
# LassoTuned__PowerTransformer                           False
# LassoTuned__LogTransformer(ln)                         False
#
#                                 LassoTuned__LogTransformer(ln)
# LassoTuned                                               False
# LassoTuned__Quantile(normal)                             False
# LassoTuned__Quantile(uniform)                            False
# LassoTuned__PowerTransformer                             False
# LassoTuned__LogTransformer(ln)                           False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:              LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned         1.0                      0.000101
#
#             LassoTuned__Quantile(uniform)  LassoTuned__PowerTransformer  \
# LassoTuned                       0.322199                      0.089686
#
#             LassoTuned__LogTransformer(ln)
# LassoTuned                        0.023652
# sign diffs             LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned       False                          True
#
#             LassoTuned__Quantile(uniform)  LassoTuned__PowerTransformer  \
# LassoTuned                          False                         False
#
#             LassoTuned__LogTransformer(ln)
# LassoTuned                           False
# ##############################################
# average improvement compared with the first column:
#                                   LassoTuned
# LassoTuned__Quantile(normal)      26.385988
# LassoTuned__Quantile(uniform)     11.761352
# LassoTuned__PowerTransformer   -6566.397169
# LassoTuned__LogTransformer(ln)    12.150554

# %% [markdown]
# ## Ridge

# %%
clf = "RidgeRegressionTuned"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729          15.66  0.003511
# Iman Davenport  0.05       2.633532       5.790468  0.001053
#
#                significant? (test stat > crit value)
# Friedman test                                   True
# Iman Davenport                                  True
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                            average rank  standard deviation
# RidgeRegressionTuned                              4.05            0.788987
# RidgeRegressionTuned__Quantile(normal)            1.60            0.768115
# RidgeRegressionTuned__Quantile(uniform)           3.85            1.550000
# RidgeRegressionTuned__PowerTransformer            2.80            0.900000
# RidgeRegressionTuned__LogTransformer(ln)          2.70            1.208305
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                           RidgeRegressionTuned  \
# RidgeRegressionTuned                                   0-10-0
# RidgeRegressionTuned__Quantile(normal)                 0-0-10
# RidgeRegressionTuned__Quantile(uniform)                 6-1-3
# RidgeRegressionTuned__PowerTransformer                  1-0-9
# RidgeRegressionTuned__LogTransformer(ln)                2-0-8
#
#                                          RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                                     10-0-0
# RidgeRegressionTuned__Quantile(normal)                                   0-10-0
# RidgeRegressionTuned__Quantile(uniform)                                   8-0-2
# RidgeRegressionTuned__PowerTransformer                                    8-1-1
# RidgeRegressionTuned__LogTransformer(ln)                                  7-1-2
#
#                                          RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                                       3-1-6
# RidgeRegressionTuned__Quantile(normal)                                     2-0-8
# RidgeRegressionTuned__Quantile(uniform)                                   0-10-0
# RidgeRegressionTuned__PowerTransformer                                     3-0-7
# RidgeRegressionTuned__LogTransformer(ln)                                   3-0-7
#
#                                          RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                                      9-0-1
# RidgeRegressionTuned__Quantile(normal)                                    1-1-8
# RidgeRegressionTuned__Quantile(uniform)                                   7-0-3
# RidgeRegressionTuned__PowerTransformer                                   0-10-0
# RidgeRegressionTuned__LogTransformer(ln)                                  3-2-5
#
#                                          RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                                        8-0-2
# RidgeRegressionTuned__Quantile(normal)                                      2-1-7
# RidgeRegressionTuned__Quantile(uniform)                                     7-0-3
# RidgeRegressionTuned__PowerTransformer                                      5-2-3
# RidgeRegressionTuned__LogTransformer(ln)                                   0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                            RidgeRegressionTuned  \
# RidgeRegressionTuned                                  1.000000
# RidgeRegressionTuned__Quantile(normal)                0.004822
# RidgeRegressionTuned__Quantile(uniform)               0.900000
# RidgeRegressionTuned__PowerTransformer                0.393897
# RidgeRegressionTuned__LogTransformer(ln)              0.312322
#
#                                           RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                                    0.004822
# RidgeRegressionTuned__Quantile(normal)                                  1.000000
# RidgeRegressionTuned__Quantile(uniform)                                 0.012728
# RidgeRegressionTuned__PowerTransformer                                  0.437421
# RidgeRegressionTuned__LogTransformer(ln)                                0.522486
#
#                                           RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                                     0.900000
# RidgeRegressionTuned__Quantile(normal)                                   0.012728
# RidgeRegressionTuned__Quantile(uniform)                                  1.000000
# RidgeRegressionTuned__PowerTransformer                                   0.562614
# RidgeRegressionTuned__LogTransformer(ln)                                 0.481073
#
#                                           RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                                    0.393897
# RidgeRegressionTuned__Quantile(normal)                                  0.437421
# RidgeRegressionTuned__Quantile(uniform)                                 0.562614
# RidgeRegressionTuned__PowerTransformer                                  1.000000
# RidgeRegressionTuned__LogTransformer(ln)                                0.900000
#
#                                           RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                                      0.312322
# RidgeRegressionTuned__Quantile(normal)                                    0.522486
# RidgeRegressionTuned__Quantile(uniform)                                   0.481073
# RidgeRegressionTuned__PowerTransformer                                    0.900000
# RidgeRegressionTuned__LogTransformer(ln)                                  1.000000
# sign diffs                                           RidgeRegressionTuned  \
# RidgeRegressionTuned                                     False
# RidgeRegressionTuned__Quantile(normal)                    True
# RidgeRegressionTuned__Quantile(uniform)                  False
# RidgeRegressionTuned__PowerTransformer                   False
# RidgeRegressionTuned__LogTransformer(ln)                 False
#
#                                           RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                                        True
# RidgeRegressionTuned__Quantile(normal)                                     False
# RidgeRegressionTuned__Quantile(uniform)                                     True
# RidgeRegressionTuned__PowerTransformer                                     False
# RidgeRegressionTuned__LogTransformer(ln)                                   False
#
#                                           RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                                        False
# RidgeRegressionTuned__Quantile(normal)                                       True
# RidgeRegressionTuned__Quantile(uniform)                                     False
# RidgeRegressionTuned__PowerTransformer                                      False
# RidgeRegressionTuned__LogTransformer(ln)                                    False
#
#                                           RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                                       False
# RidgeRegressionTuned__Quantile(normal)                                     False
# RidgeRegressionTuned__Quantile(uniform)                                    False
# RidgeRegressionTuned__PowerTransformer                                     False
# RidgeRegressionTuned__LogTransformer(ln)                                   False
#
#                                           RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                                         False
# RidgeRegressionTuned__Quantile(normal)                                       False
# RidgeRegressionTuned__Quantile(uniform)                                      False
# RidgeRegressionTuned__PowerTransformer                                       False
# RidgeRegressionTuned__LogTransformer(ln)                                     False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:                        RidgeRegressionTuned  \
# RidgeRegressionTuned                   1.0
#
#                       RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                0.000531
#
#                       RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                 0.777297
#
#                       RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                  0.0771
#
#                       RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                  0.056238
# sign diffs                       RidgeRegressionTuned  \
# RidgeRegressionTuned                 False
#
#                       RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                    True
#
#                       RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                    False
#
#                       RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                   False
#
#                       RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                     False
# ##############################################
# average improvement compared with the first column:
#                                            RidgeRegressionTuned
# RidgeRegressionTuned__Quantile(normal)               23.836438
# RidgeRegressionTuned__Quantile(uniform)               2.585842
# RidgeRegressionTuned__PowerTransformer                2.538351
# RidgeRegressionTuned__LogTransformer(ln)              1.240225

# %% [markdown]
# ## Gradient Boosted Trees Regressor

# %%
clf = "GradientBoostingRegressorWrapper"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729           5.66  0.226019
# Iman Davenport  0.05       2.633532       1.483401  0.227608
#
#                significant? (test stat > crit value)
# Friedman test                                  False
# Iman Davenport                                 False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                                      average rank  \
# GradientBoostingRegressorWrapper                            2.05
# GradientBoostingRegressorWrapper__Quantile(normal)          3.30
# GradientBoostingRegressorWrapper__Quantile(unif...          3.60
# GradientBoostingRegressorWrapper__PowerTransformer          3.20
# GradientBoostingRegressorWrapper__LogTransforme...          2.85
#
#                                                     standard deviation
# GradientBoostingRegressorWrapper                              0.960469
# GradientBoostingRegressorWrapper__Quantile(normal)            1.417745
# GradientBoostingRegressorWrapper__Quantile(unif...            1.113553
# GradientBoostingRegressorWrapper__PowerTransformer            1.469694
# GradientBoostingRegressorWrapper__LogTransforme...            1.342572
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                                     GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                                             0-10-0
# GradientBoostingRegressorWrapper__Quantile(normal)                            6-1-3
# GradientBoostingRegressorWrapper__Quantile(unif...                            9-0-1
# GradientBoostingRegressorWrapper__PowerTransformer                            6-3-1
# GradientBoostingRegressorWrapper__LogTransforme...                            5-3-2
#
#                                                    GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                                                3-1-6
# GradientBoostingRegressorWrapper__Quantile(normal)                                             0-10-0
# GradientBoostingRegressorWrapper__Quantile(unif...                                              5-0-5
# GradientBoostingRegressorWrapper__PowerTransformer                                              5-0-5
# GradientBoostingRegressorWrapper__LogTransforme...                                              4-1-5
#
#                                                    GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                                                1-0-9
# GradientBoostingRegressorWrapper__Quantile(normal)                                              5-0-5
# GradientBoostingRegressorWrapper__Quantile(unif...                                             0-10-0
# GradientBoostingRegressorWrapper__PowerTransformer                                              5-0-5
# GradientBoostingRegressorWrapper__LogTransforme...                                              3-0-7
#
#                                                    GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                                                1-3-6
# GradientBoostingRegressorWrapper__Quantile(normal)                                              5-0-5
# GradientBoostingRegressorWrapper__Quantile(unif...                                              5-0-5
# GradientBoostingRegressorWrapper__PowerTransformer                                             0-10-0
# GradientBoostingRegressorWrapper__LogTransforme...                                              4-4-2
#
#                                                    GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                                                2-3-5
# GradientBoostingRegressorWrapper__Quantile(normal)                                              5-1-4
# GradientBoostingRegressorWrapper__Quantile(unif...                                              7-0-3
# GradientBoostingRegressorWrapper__PowerTransformer                                              2-4-4
# GradientBoostingRegressorWrapper__LogTransforme...                                             0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                                      GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                                            1.000000
# GradientBoostingRegressorWrapper__Quantile(normal)                          0.393897
# GradientBoostingRegressorWrapper__Quantile(unif...                          0.182487
# GradientBoostingRegressorWrapper__PowerTransformer                          0.481073
# GradientBoostingRegressorWrapper__LogTransforme...                          0.763265
#
#                                                     GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                                             0.393897
# GradientBoostingRegressorWrapper__Quantile(normal)                                           1.000000
# GradientBoostingRegressorWrapper__Quantile(unif...                                           0.900000
# GradientBoostingRegressorWrapper__PowerTransformer                                           0.900000
# GradientBoostingRegressorWrapper__LogTransforme...                                           0.900000
#
#                                                     GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                                             0.182487
# GradientBoostingRegressorWrapper__Quantile(normal)                                           0.900000
# GradientBoostingRegressorWrapper__Quantile(unif...                                           1.000000
# GradientBoostingRegressorWrapper__PowerTransformer                                           0.900000
# GradientBoostingRegressorWrapper__LogTransforme...                                           0.803399
#
#                                                     GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                                             0.481073
# GradientBoostingRegressorWrapper__Quantile(normal)                                           0.900000
# GradientBoostingRegressorWrapper__Quantile(unif...                                           0.900000
# GradientBoostingRegressorWrapper__PowerTransformer                                           1.000000
# GradientBoostingRegressorWrapper__LogTransforme...                                           0.900000
#
#                                                     GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                                             0.763265
# GradientBoostingRegressorWrapper__Quantile(normal)                                           0.900000
# GradientBoostingRegressorWrapper__Quantile(unif...                                           0.803399
# GradientBoostingRegressorWrapper__PowerTransformer                                           0.900000
# GradientBoostingRegressorWrapper__LogTransforme...                                           1.000000
# sign diffs                                                     GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                                               False
# GradientBoostingRegressorWrapper__Quantile(normal)                             False
# GradientBoostingRegressorWrapper__Quantile(unif...                             False
# GradientBoostingRegressorWrapper__PowerTransformer                             False
# GradientBoostingRegressorWrapper__LogTransforme...                             False
#
#                                                     GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
#
#                                                     GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
#
#                                                     GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
#
#                                                     GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:                                    GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                               1.0
#
#                                   GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                             0.0771
#
#                                   GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                           0.028377
#
#                                   GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                           0.103876
#
#                                   GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                           0.257899
# sign diffs                                   GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                             False
#
#                                   GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                              False
#
#                                   GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                              False
#
#                                   GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                              False
#
#                                   GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                              False
# ##############################################
# average improvement compared with the first column:
#                                                      GradientBoostingRegressorWrapper
# GradientBoostingRegressorWrapper__Quantile(normal)                        -45.865840
# GradientBoostingRegressorWrapper__Quantile(unif...                        -33.740242
# GradientBoostingRegressorWrapper__PowerTransformer                      -9006.749713
# GradientBoostingRegressorWrapper__LogTransforme...                        -37.643775

# %% [markdown]
# ## SVR

# %%
clf = "SupportVectorRegressorWrapper"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729          16.54  0.002374
# Iman Davenport  0.05       2.633532       6.345269  0.000569
#
#                significant? (test stat > crit value)
# Friedman test                                   True
# Iman Davenport                                  True
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                                     average rank  \
# SupportVectorRegressorWrapper                              4.50
# SupportVectorRegressorWrapper__Quantile(normal)            1.85
# SupportVectorRegressorWrapper__Quantile(uniform)           3.10
# SupportVectorRegressorWrapper__PowerTransformer            3.25
# SupportVectorRegressorWrapper__LogTransformer(ln)          2.30
#
#                                                    standard deviation
# SupportVectorRegressorWrapper                                1.024695
# SupportVectorRegressorWrapper__Quantile(normal)              0.895824
# SupportVectorRegressorWrapper__Quantile(uniform)             1.135782
# SupportVectorRegressorWrapper__PowerTransformer              0.928709
# SupportVectorRegressorWrapper__LogTransformer(ln)            1.345362
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                                    SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                                            0-10-0
# SupportVectorRegressorWrapper__Quantile(normal)                          0-0-10
# SupportVectorRegressorWrapper__Quantile(uniform)                          1-0-9
# SupportVectorRegressorWrapper__PowerTransformer                           2-0-8
# SupportVectorRegressorWrapper__LogTransformer(ln)                         2-0-8
#
#                                                   SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                                              10-0-0
# SupportVectorRegressorWrapper__Quantile(normal)                                            0-10-0
# SupportVectorRegressorWrapper__Quantile(uniform)                                            7-0-3
# SupportVectorRegressorWrapper__PowerTransformer                                             8-1-1
# SupportVectorRegressorWrapper__LogTransformer(ln)                                           6-0-4
#
#                                                   SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                                                9-0-1
# SupportVectorRegressorWrapper__Quantile(normal)                                              3-0-7
# SupportVectorRegressorWrapper__Quantile(uniform)                                            0-10-0
# SupportVectorRegressorWrapper__PowerTransformer                                              4-0-6
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            3-0-7
#
#                                                   SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                                               8-0-2
# SupportVectorRegressorWrapper__Quantile(normal)                                             1-1-8
# SupportVectorRegressorWrapper__Quantile(uniform)                                            6-0-4
# SupportVectorRegressorWrapper__PowerTransformer                                            0-10-0
# SupportVectorRegressorWrapper__LogTransformer(ln)                                           2-0-8
#
#                                                   SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                                                 8-0-2
# SupportVectorRegressorWrapper__Quantile(normal)                                               4-0-6
# SupportVectorRegressorWrapper__Quantile(uniform)                                              7-0-3
# SupportVectorRegressorWrapper__PowerTransformer                                               8-0-2
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                                     SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                                           1.000000
# SupportVectorRegressorWrapper__Quantile(normal)                         0.001673
# SupportVectorRegressorWrapper__Quantile(uniform)                        0.275862
# SupportVectorRegressorWrapper__PowerTransformer                         0.393897
# SupportVectorRegressorWrapper__LogTransformer(ln)                       0.016000
#
#                                                    SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                                             0.001673
# SupportVectorRegressorWrapper__Quantile(normal)                                           1.000000
# SupportVectorRegressorWrapper__Quantile(uniform)                                          0.393897
# SupportVectorRegressorWrapper__PowerTransformer                                           0.275862
# SupportVectorRegressorWrapper__LogTransformer(ln)                                         0.900000
#
#                                                    SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                                              0.275862
# SupportVectorRegressorWrapper__Quantile(normal)                                            0.393897
# SupportVectorRegressorWrapper__Quantile(uniform)                                           1.000000
# SupportVectorRegressorWrapper__PowerTransformer                                            0.900000
# SupportVectorRegressorWrapper__LogTransformer(ln)                                          0.763265
#
#                                                    SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                                             0.393897
# SupportVectorRegressorWrapper__Quantile(normal)                                           0.275862
# SupportVectorRegressorWrapper__Quantile(uniform)                                          0.900000
# SupportVectorRegressorWrapper__PowerTransformer                                           1.000000
# SupportVectorRegressorWrapper__LogTransformer(ln)                                         0.642876
#
#                                                    SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                                               0.016000
# SupportVectorRegressorWrapper__Quantile(normal)                                             0.900000
# SupportVectorRegressorWrapper__Quantile(uniform)                                            0.763265
# SupportVectorRegressorWrapper__PowerTransformer                                             0.642876
# SupportVectorRegressorWrapper__LogTransformer(ln)                                           1.000000
# sign diffs                                                    SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                                              False
# SupportVectorRegressorWrapper__Quantile(normal)                             True
# SupportVectorRegressorWrapper__Quantile(uniform)                           False
# SupportVectorRegressorWrapper__PowerTransformer                            False
# SupportVectorRegressorWrapper__LogTransformer(ln)                           True
#
#                                                    SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                                                 True
# SupportVectorRegressorWrapper__Quantile(normal)                                              False
# SupportVectorRegressorWrapper__Quantile(uniform)                                             False
# SupportVectorRegressorWrapper__PowerTransformer                                              False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            False
#
#                                                    SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                                                 False
# SupportVectorRegressorWrapper__Quantile(normal)                                               False
# SupportVectorRegressorWrapper__Quantile(uniform)                                              False
# SupportVectorRegressorWrapper__PowerTransformer                                               False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                             False
#
#                                                    SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                                                False
# SupportVectorRegressorWrapper__Quantile(normal)                                              False
# SupportVectorRegressorWrapper__Quantile(uniform)                                             False
# SupportVectorRegressorWrapper__PowerTransformer                                              False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            False
#
#                                                    SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                                                   True
# SupportVectorRegressorWrapper__Quantile(normal)                                                False
# SupportVectorRegressorWrapper__Quantile(uniform)                                               False
# SupportVectorRegressorWrapper__PowerTransformer                                                False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                              False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:                                 SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                            1.0
#
#                                SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                         0.000178
#
#                                SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                          0.047715
#
#                                SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                           0.0771
#
#                                SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                           0.001863
# sign diffs                                SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                          False
#
#                                SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                             True
#
#                                SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                             False
#
#                                SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                            False
#
#                                SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                               True
# ##############################################
# average improvement compared with the first column:
#                                                     SupportVectorRegressorWrapper
# SupportVectorRegressorWrapper__Quantile(normal)                        57.661726
# SupportVectorRegressorWrapper__Quantile(uniform)                       47.520206
# SupportVectorRegressorWrapper__PowerTransformer                     -8795.686054
# SupportVectorRegressorWrapper__LogTransformer(ln)                   -5979.096112
