# %%
import os

os.environ['DATA_DIR'] = "/home/loren/Code/evaluation/data/datasets"

# %%
from multiple_classifiers import friedman_test, nemenyi_friedman_test, bonferroni_dunn_test
import pandas as pd

from src.experiments.print_results import get_results
from src.experiments.data import datasets, imbalanced_distribution_datasets
from src.experiments.print_results import all_metrics
from src.experiments.utils import Keys, get_clf_full_name

# %% [markdown]
# # Import the results

# %%
from src.experiments.imbalanced_distribution import DEFAULT_CLFS

datasets_ = list(imbalanced_distribution_datasets.keys())
metric = Keys.average_mape
experiment_ = 'imbalanced_distribution'
suffix_ = ""
from_pkl_ = False
clfs = DEFAULT_CLFS
feature_transformer_name = None
incl_transformers = [None, Keys.transformer_quantile_normal, Keys.transformer_quantile_uniform,
                             Keys.transformer_powertransformer, Keys.transformer_lntransformer]
column_order = [get_clf_full_name(clf.name, transformer, feature_transformer_name).replace(' ', '')
                                              for clf in clfs for transformer in incl_transformers]

# %%
all_results = {}
for clf in clfs:
    column_order = [get_clf_full_name(clf.name, transformer, feature_transformer_name).replace(' ', '') for transformer in incl_transformers]
    all_results[clf.name] = get_results(datasets_, metric.replace(' ', ''), experiment_,
                                    # present_substring=f"__f_{feature_transformer_name}".replace(' ', ''),
                                    # absent_substring='__f_',
                                    suffix=suffix_, from_text=not from_pkl_,
                                    column_order=column_order)

# %% [markdown]
# # Run the statistical tests

# %%
def average_improvement(x, lower_is_better=False):
    improvements = []
    baseline = x[[x.columns[0]]].values
    for c in x.columns[1:]:
        if lower_is_better:
            improvements_column = (baseline - x[[c]].values) / baseline * 100
        else:
            improvements_column = (x[[c]].values - baseline)
        improvements.append(improvements_column.mean())
    return pd.DataFrame(improvements, index=list(x.columns[1:]), columns=[x.columns[0]])

# %%
def run_stats(to_compare, control: str, lower_is_better=True):
    from classifier_comparisons import BlockDesign
    # pd.set_option('display.max_rows', None)
    # pd.set_option('display.max_columns', None)

    block_design = BlockDesign(to_compare, threshold=0.001, precision=3, higher_is_better=(not lower_is_better))
    test_results = friedman_test(block_design, alpha=0.05)
    print("test results: \n", test_results)
    print("##############################################")
    average_ranks = block_design.to_ranks()
    print("average ranks: \n", average_ranks)
    print("##############################################")
    wins = BlockDesign(to_compare).to_wins_ties_losses()
    print("wins ties losses: \n", wins)
    print("##############################################")
    p_values, sign_diffs = nemenyi_friedman_test(block_design, alpha=0.05)
    print("p values: ", p_values.data)
    print("sign diffs", sign_diffs.data)
    print("##############################################")

    p_values, sign_diffs = bonferroni_dunn_test(block_design, alpha=0.05, control=control)
    print("p values: ", p_values.data)
    print("sign diffs", sign_diffs.data)

    print("##############################################")
    print("average improvement compared with the first column: \n", average_improvement(to_compare, lower_is_better))

# %% [markdown]
# ## Lasso

# %%
clf = "LassoTuned"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729           9.16  0.057222
# Iman Davenport  0.05       2.633532       2.673152   0.04747
#
#                significant? (test stat > crit value)
# Friedman test                                  False
# Iman Davenport                                  True
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                  average rank  standard deviation
# LassoTuned                              4.15            1.141271
# LassoTuned__Quantile(normal)            2.35            1.096586
# LassoTuned__Quantile(uniform)           3.35            1.225765
# LassoTuned__PowerTransformer            2.75            1.030776
# LassoTuned__LogTransformer(ln)          2.40            1.445683
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                 LassoTuned LassoTuned__Quantile(normal)  \
# LassoTuned                         0-10-0                        9-1-0
# LassoTuned__Quantile(normal)        0-1-9                       0-10-0
# LassoTuned__Quantile(uniform)       2-1-7                        6-1-3
# LassoTuned__PowerTransformer        3-0-7                        6-0-4
# LassoTuned__LogTransformer(ln)      2-1-7                        4-1-5
#
#                                LassoTuned__Quantile(uniform)  \
# LassoTuned                                             7-1-2
# LassoTuned__Quantile(normal)                           3-1-6
# LassoTuned__Quantile(uniform)                         0-10-0
# LassoTuned__PowerTransformer                           3-0-7
# LassoTuned__LogTransformer(ln)                         2-1-7
#
#                                LassoTuned__PowerTransformer  \
# LassoTuned                                            7-0-3
# LassoTuned__Quantile(normal)                          4-0-6
# LassoTuned__Quantile(uniform)                         7-0-3
# LassoTuned__PowerTransformer                         0-10-0
# LassoTuned__LogTransformer(ln)                        4-2-4
#
#                                LassoTuned__LogTransformer(ln)
# LassoTuned                                              7-1-2
# LassoTuned__Quantile(normal)                            5-1-4
# LassoTuned__Quantile(uniform)                           7-1-2
# LassoTuned__PowerTransformer                            4-2-4
# LassoTuned__LogTransformer(ln)                         0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                  LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned                        1.000000                      0.081019
# LassoTuned__Quantile(normal)      0.081019                      1.000000
# LassoTuned__Quantile(uniform)     0.763265                      0.602746
# LassoTuned__PowerTransformer      0.275862                      0.900000
# LassoTuned__LogTransformer(ln)    0.096243                      0.900000
#
#                                 LassoTuned__Quantile(uniform)  \
# LassoTuned                                           0.763265
# LassoTuned__Quantile(normal)                         0.602746
# LassoTuned__Quantile(uniform)                        1.000000
# LassoTuned__PowerTransformer                         0.900000
# LassoTuned__LogTransformer(ln)                       0.642876
#
#                                 LassoTuned__PowerTransformer  \
# LassoTuned                                          0.275862
# LassoTuned__Quantile(normal)                        0.900000
# LassoTuned__Quantile(uniform)                       0.900000
# LassoTuned__PowerTransformer                        1.000000
# LassoTuned__LogTransformer(ln)                      0.900000
#
#                                 LassoTuned__LogTransformer(ln)
# LassoTuned                                            0.096243
# LassoTuned__Quantile(normal)                          0.900000
# LassoTuned__Quantile(uniform)                         0.642876
# LassoTuned__PowerTransformer                          0.900000
# LassoTuned__LogTransformer(ln)                        1.000000
# sign diffs                                 LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned                           False                         False
# LassoTuned__Quantile(normal)         False                         False
# LassoTuned__Quantile(uniform)        False                         False
# LassoTuned__PowerTransformer         False                         False
# LassoTuned__LogTransformer(ln)       False                         False
#
#                                 LassoTuned__Quantile(uniform)  \
# LassoTuned                                              False
# LassoTuned__Quantile(normal)                            False
# LassoTuned__Quantile(uniform)                           False
# LassoTuned__PowerTransformer                            False
# LassoTuned__LogTransformer(ln)                          False
#
#                                 LassoTuned__PowerTransformer  \
# LassoTuned                                             False
# LassoTuned__Quantile(normal)                           False
# LassoTuned__Quantile(uniform)                          False
# LassoTuned__PowerTransformer                           False
# LassoTuned__LogTransformer(ln)                         False
#
#                                 LassoTuned__LogTransformer(ln)
# LassoTuned                                               False
# LassoTuned__Quantile(normal)                             False
# LassoTuned__Quantile(uniform)                            False
# LassoTuned__PowerTransformer                             False
# LassoTuned__LogTransformer(ln)                           False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:              LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned         1.0                      0.010909
#
#             LassoTuned__Quantile(uniform)  LassoTuned__PowerTransformer  \
# LassoTuned                       0.257899                      0.047715
#
#             LassoTuned__LogTransformer(ln)
# LassoTuned                        0.013328
# sign diffs             LassoTuned  LassoTuned__Quantile(normal)  \
# LassoTuned       False                          True
#
#             LassoTuned__Quantile(uniform)  LassoTuned__PowerTransformer  \
# LassoTuned                          False                         False
#
#             LassoTuned__LogTransformer(ln)
# LassoTuned                           False
# ##############################################
# average improvement compared with the first column:
#                                    LassoTuned
# LassoTuned__Quantile(normal)    2.481729e+01
# LassoTuned__Quantile(uniform)   2.004169e+01
# LassoTuned__PowerTransformer   -3.097815e+06
# LassoTuned__LogTransformer(ln) -1.092886e+60

# %% [markdown]
# ## Ridge

# %%
clf = "RidgeRegressionTuned"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729           9.26  0.054919
# Iman Davenport  0.05       2.633532       2.711126  0.045168
#
#                significant? (test stat > crit value)
# Friedman test                                  False
# Iman Davenport                                  True
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                            average rank  standard deviation
# RidgeRegressionTuned                              4.25            0.981071
# RidgeRegressionTuned__Quantile(normal)            2.45            1.192686
# RidgeRegressionTuned__Quantile(uniform)           3.20            1.400000
# RidgeRegressionTuned__PowerTransformer            2.50            0.547723
# RidgeRegressionTuned__LogTransformer(ln)          2.60            1.374773
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                           RidgeRegressionTuned  \
# RidgeRegressionTuned                                   0-10-0
# RidgeRegressionTuned__Quantile(normal)                  0-2-8
# RidgeRegressionTuned__Quantile(uniform)                 2-1-7
# RidgeRegressionTuned__PowerTransformer                  1-1-8
# RidgeRegressionTuned__LogTransformer(ln)                2-1-7
#
#                                          RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                                      8-2-0
# RidgeRegressionTuned__Quantile(normal)                                   0-10-0
# RidgeRegressionTuned__Quantile(uniform)                                   6-1-3
# RidgeRegressionTuned__PowerTransformer                                    5-1-4
# RidgeRegressionTuned__LogTransformer(ln)                                  4-1-5
#
#                                          RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                                       7-1-2
# RidgeRegressionTuned__Quantile(normal)                                     3-1-6
# RidgeRegressionTuned__Quantile(uniform)                                   0-10-0
# RidgeRegressionTuned__PowerTransformer                                     3-1-6
# RidgeRegressionTuned__LogTransformer(ln)                                   3-1-6
#
#                                          RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                                      8-1-1
# RidgeRegressionTuned__Quantile(normal)                                    4-1-5
# RidgeRegressionTuned__Quantile(uniform)                                   6-1-3
# RidgeRegressionTuned__PowerTransformer                                   0-10-0
# RidgeRegressionTuned__LogTransformer(ln)                                  4-3-3
#
#                                          RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                                        7-1-2
# RidgeRegressionTuned__Quantile(normal)                                      5-1-4
# RidgeRegressionTuned__Quantile(uniform)                                     6-1-3
# RidgeRegressionTuned__PowerTransformer                                      3-3-4
# RidgeRegressionTuned__LogTransformer(ln)                                   0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                            RidgeRegressionTuned  \
# RidgeRegressionTuned                                  1.000000
# RidgeRegressionTuned__Quantile(normal)                0.081019
# RidgeRegressionTuned__Quantile(uniform)               0.562614
# RidgeRegressionTuned__PowerTransformer                0.096243
# RidgeRegressionTuned__LogTransformer(ln)              0.134087
#
#                                           RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                                    0.081019
# RidgeRegressionTuned__Quantile(normal)                                  1.000000
# RidgeRegressionTuned__Quantile(uniform)                                 0.803399
# RidgeRegressionTuned__PowerTransformer                                  0.900000
# RidgeRegressionTuned__LogTransformer(ln)                                0.900000
#
#                                           RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                                     0.562614
# RidgeRegressionTuned__Quantile(normal)                                   0.803399
# RidgeRegressionTuned__Quantile(uniform)                                  1.000000
# RidgeRegressionTuned__PowerTransformer                                   0.843526
# RidgeRegressionTuned__LogTransformer(ln)                                 0.900000
#
#                                           RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                                    0.096243
# RidgeRegressionTuned__Quantile(normal)                                  0.900000
# RidgeRegressionTuned__Quantile(uniform)                                 0.843526
# RidgeRegressionTuned__PowerTransformer                                  1.000000
# RidgeRegressionTuned__LogTransformer(ln)                                0.900000
#
#                                           RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                                      0.134087
# RidgeRegressionTuned__Quantile(normal)                                    0.900000
# RidgeRegressionTuned__Quantile(uniform)                                   0.900000
# RidgeRegressionTuned__PowerTransformer                                    0.900000
# RidgeRegressionTuned__LogTransformer(ln)                                  1.000000
# sign diffs                                           RidgeRegressionTuned  \
# RidgeRegressionTuned                                     False
# RidgeRegressionTuned__Quantile(normal)                   False
# RidgeRegressionTuned__Quantile(uniform)                  False
# RidgeRegressionTuned__PowerTransformer                   False
# RidgeRegressionTuned__LogTransformer(ln)                 False
#
#                                           RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                                       False
# RidgeRegressionTuned__Quantile(normal)                                     False
# RidgeRegressionTuned__Quantile(uniform)                                    False
# RidgeRegressionTuned__PowerTransformer                                     False
# RidgeRegressionTuned__LogTransformer(ln)                                   False
#
#                                           RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                                        False
# RidgeRegressionTuned__Quantile(normal)                                      False
# RidgeRegressionTuned__Quantile(uniform)                                     False
# RidgeRegressionTuned__PowerTransformer                                      False
# RidgeRegressionTuned__LogTransformer(ln)                                    False
#
#                                           RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                                       False
# RidgeRegressionTuned__Quantile(normal)                                     False
# RidgeRegressionTuned__Quantile(uniform)                                    False
# RidgeRegressionTuned__PowerTransformer                                     False
# RidgeRegressionTuned__LogTransformer(ln)                                   False
#
#                                           RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                                         False
# RidgeRegressionTuned__Quantile(normal)                                       False
# RidgeRegressionTuned__Quantile(uniform)                                      False
# RidgeRegressionTuned__PowerTransformer                                       False
# RidgeRegressionTuned__LogTransformer(ln)                                     False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:                        RidgeRegressionTuned  \
# RidgeRegressionTuned                   1.0
#
#                       RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                0.010909
#
#                       RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                 0.137564
#
#                       RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                0.013328
#
#                       RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                  0.019624
# sign diffs                       RidgeRegressionTuned  \
# RidgeRegressionTuned                 False
#
#                       RidgeRegressionTuned__Quantile(normal)  \
# RidgeRegressionTuned                                    True
#
#                       RidgeRegressionTuned__Quantile(uniform)  \
# RidgeRegressionTuned                                    False
#
#                       RidgeRegressionTuned__PowerTransformer  \
# RidgeRegressionTuned                                   False
#
#                       RidgeRegressionTuned__LogTransformer(ln)
# RidgeRegressionTuned                                     False
# ##############################################
# average improvement compared with the first column:
#                                            RidgeRegressionTuned
# RidgeRegressionTuned__Quantile(normal)            2.467009e+01
# RidgeRegressionTuned__Quantile(uniform)           2.006368e+01
# RidgeRegressionTuned__PowerTransformer            2.083256e+01
# RidgeRegressionTuned__LogTransformer(ln)         -4.345382e+97

# %% [markdown]
# ## Gradient Boosted Trees Regressor

# %%
clf = "GradientBoostingRegressorWrapper"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729            7.5  0.111709
# Iman Davenport  0.05       2.633532       2.076923  0.104183
#
#                significant? (test stat > crit value)
# Friedman test                                  False
# Iman Davenport                                 False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                                      average rank  \
# GradientBoostingRegressorWrapper                            3.75
# GradientBoostingRegressorWrapper__Quantile(normal)          3.40
# GradientBoostingRegressorWrapper__Quantile(unif...          3.10
# GradientBoostingRegressorWrapper__PowerTransformer          2.80
# GradientBoostingRegressorWrapper__LogTransforme...          1.95
#
#                                                     standard deviation
# GradientBoostingRegressorWrapper                              1.006231
# GradientBoostingRegressorWrapper__Quantile(normal)            1.513275
# GradientBoostingRegressorWrapper__Quantile(unif...            1.220656
# GradientBoostingRegressorWrapper__PowerTransformer            1.228821
# GradientBoostingRegressorWrapper__LogTransforme...            0.934077
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                                     GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                                             0-10-0
# GradientBoostingRegressorWrapper__Quantile(normal)                            5-1-4
# GradientBoostingRegressorWrapper__Quantile(unif...                            2-3-5
# GradientBoostingRegressorWrapper__PowerTransformer                            2-2-6
# GradientBoostingRegressorWrapper__LogTransforme...                            0-3-7
#
#                                                    GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                                                4-1-5
# GradientBoostingRegressorWrapper__Quantile(normal)                                             0-10-0
# GradientBoostingRegressorWrapper__Quantile(unif...                                              3-2-5
# GradientBoostingRegressorWrapper__PowerTransformer                                              5-0-5
# GradientBoostingRegressorWrapper__LogTransforme...                                              2-1-7
#
#                                                    GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                                                5-3-2
# GradientBoostingRegressorWrapper__Quantile(normal)                                              5-2-3
# GradientBoostingRegressorWrapper__Quantile(unif...                                             0-10-0
# GradientBoostingRegressorWrapper__PowerTransformer                                              4-0-6
# GradientBoostingRegressorWrapper__LogTransforme...                                              2-1-7
#
#                                                    GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                                                6-2-2
# GradientBoostingRegressorWrapper__Quantile(normal)                                              5-0-5
# GradientBoostingRegressorWrapper__Quantile(unif...                                              6-0-4
# GradientBoostingRegressorWrapper__PowerTransformer                                             0-10-0
# GradientBoostingRegressorWrapper__LogTransforme...                                              2-4-4
#
#                                                    GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                                                7-3-0
# GradientBoostingRegressorWrapper__Quantile(normal)                                              7-1-2
# GradientBoostingRegressorWrapper__Quantile(unif...                                              7-1-2
# GradientBoostingRegressorWrapper__PowerTransformer                                              4-4-2
# GradientBoostingRegressorWrapper__LogTransforme...                                             0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                                      GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                                            1.000000
# GradientBoostingRegressorWrapper__Quantile(normal)                          0.900000
# GradientBoostingRegressorWrapper__Quantile(unif...                          0.883657
# GradientBoostingRegressorWrapper__PowerTransformer                          0.642876
# GradientBoostingRegressorWrapper__LogTransforme...                          0.081019
#
#                                                     GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                                             0.900000
# GradientBoostingRegressorWrapper__Quantile(normal)                                           1.000000
# GradientBoostingRegressorWrapper__Quantile(unif...                                           0.900000
# GradientBoostingRegressorWrapper__PowerTransformer                                           0.900000
# GradientBoostingRegressorWrapper__LogTransforme...                                           0.241843
#
#                                                     GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                                             0.883657
# GradientBoostingRegressorWrapper__Quantile(normal)                                           0.900000
# GradientBoostingRegressorWrapper__Quantile(unif...                                           1.000000
# GradientBoostingRegressorWrapper__PowerTransformer                                           0.900000
# GradientBoostingRegressorWrapper__LogTransforme...                                           0.481073
#
#                                                     GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                                             0.642876
# GradientBoostingRegressorWrapper__Quantile(normal)                                           0.900000
# GradientBoostingRegressorWrapper__Quantile(unif...                                           0.900000
# GradientBoostingRegressorWrapper__PowerTransformer                                           1.000000
# GradientBoostingRegressorWrapper__LogTransforme...                                           0.723137
#
#                                                     GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                                             0.081019
# GradientBoostingRegressorWrapper__Quantile(normal)                                           0.241843
# GradientBoostingRegressorWrapper__Quantile(unif...                                           0.481073
# GradientBoostingRegressorWrapper__PowerTransformer                                           0.723137
# GradientBoostingRegressorWrapper__LogTransforme...                                           1.000000
# sign diffs                                                     GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                                               False
# GradientBoostingRegressorWrapper__Quantile(normal)                             False
# GradientBoostingRegressorWrapper__Quantile(unif...                             False
# GradientBoostingRegressorWrapper__PowerTransformer                             False
# GradientBoostingRegressorWrapper__LogTransforme...                             False
#
#                                                     GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
#
#                                                     GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
#
#                                                     GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
#
#                                                     GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                                                False
# GradientBoostingRegressorWrapper__Quantile(normal)                                              False
# GradientBoostingRegressorWrapper__Quantile(unif...                                              False
# GradientBoostingRegressorWrapper__PowerTransformer                                              False
# GradientBoostingRegressorWrapper__LogTransforme...                                              False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:                                    GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                               1.0
#
#                                   GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                           0.620618
#
#                                   GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                           0.357971
#
#                                   GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                           0.179109
#
#                                   GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                           0.010909
# sign diffs                                   GradientBoostingRegressorWrapper  \
# GradientBoostingRegressorWrapper                             False
#
#                                   GradientBoostingRegressorWrapper__Quantile(normal)  \
# GradientBoostingRegressorWrapper                                              False
#
#                                   GradientBoostingRegressorWrapper__Quantile(uniform)  \
# GradientBoostingRegressorWrapper                                              False
#
#                                   GradientBoostingRegressorWrapper__PowerTransformer  \
# GradientBoostingRegressorWrapper                                              False
#
#                                   GradientBoostingRegressorWrapper__LogTransformer(ln)
# GradientBoostingRegressorWrapper                                               True
# ##############################################
# average improvement compared with the first column:
#                                                      GradientBoostingRegressorWrapper
# GradientBoostingRegressorWrapper__Quantile(normal)                          4.441680
# GradientBoostingRegressorWrapper__Quantile(unif...                         10.072291
# GradientBoostingRegressorWrapper__PowerTransformer                        -13.187012
# GradientBoostingRegressorWrapper__LogTransforme...                         15.698743

# %% [markdown]
# ## SVR

# %%
clf = "SupportVectorRegressorWrapper"
to_compare = all_results[clf]
run_stats(to_compare, control=to_compare.columns[0], lower_is_better=True)
# Out:
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# test results:
#                 alpha critical value test statistic   p value  \
# Friedman test   0.05       9.487729          17.02  0.001916
# Iman Davenport  0.05       2.633532       6.665796  0.000402
#
#                significant? (test stat > crit value)
# Friedman test                                   True
# Iman Davenport                                  True
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# average ranks:
#                                                     average rank  \
# SupportVectorRegressorWrapper                              4.30
# SupportVectorRegressorWrapper__Quantile(normal)            1.55
# SupportVectorRegressorWrapper__Quantile(uniform)           3.60
# SupportVectorRegressorWrapper__PowerTransformer            2.75
# SupportVectorRegressorWrapper__LogTransformer(ln)          2.80
#
#                                                    standard deviation
# SupportVectorRegressorWrapper                                1.187434
# SupportVectorRegressorWrapper__Quantile(normal)              0.471699
# SupportVectorRegressorWrapper__Quantile(uniform)             1.200000
# SupportVectorRegressorWrapper__PowerTransformer              0.680074
# SupportVectorRegressorWrapper__LogTransformer(ln)            1.400000
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Number of compared methods: 5
# Number of datasets: 10
# WARNING: threshold-based rank computation is not perfect. Consider lowering the precision.
# wins ties losses:
#                                                    SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                                            0-10-0
# SupportVectorRegressorWrapper__Quantile(normal)                           0-1-9
# SupportVectorRegressorWrapper__Quantile(uniform)                          2-1-7
# SupportVectorRegressorWrapper__PowerTransformer                           2-0-8
# SupportVectorRegressorWrapper__LogTransformer(ln)                         2-0-8
#
#                                                   SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                                               9-1-0
# SupportVectorRegressorWrapper__Quantile(normal)                                            0-10-0
# SupportVectorRegressorWrapper__Quantile(uniform)                                            9-0-1
# SupportVectorRegressorWrapper__PowerTransformer                                             9-1-0
# SupportVectorRegressorWrapper__LogTransformer(ln)                                           7-0-3
#
#                                                   SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                                                7-1-2
# SupportVectorRegressorWrapper__Quantile(normal)                                              1-0-9
# SupportVectorRegressorWrapper__Quantile(uniform)                                            0-10-0
# SupportVectorRegressorWrapper__PowerTransformer                                              2-0-8
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            3-0-7
#
#                                                   SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                                               8-0-2
# SupportVectorRegressorWrapper__Quantile(normal)                                             0-1-9
# SupportVectorRegressorWrapper__Quantile(uniform)                                            8-0-2
# SupportVectorRegressorWrapper__PowerTransformer                                            0-10-0
# SupportVectorRegressorWrapper__LogTransformer(ln)                                           6-0-4
#
#                                                   SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                                                 8-0-2
# SupportVectorRegressorWrapper__Quantile(normal)                                               3-0-7
# SupportVectorRegressorWrapper__Quantile(uniform)                                              7-0-3
# SupportVectorRegressorWrapper__PowerTransformer                                               4-0-6
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            0-10-0
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# p values:                                                     SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                                           1.000000
# SupportVectorRegressorWrapper__Quantile(normal)                         0.001000
# SupportVectorRegressorWrapper__Quantile(uniform)                        0.843526
# SupportVectorRegressorWrapper__PowerTransformer                         0.182487
# SupportVectorRegressorWrapper__LogTransformer(ln)                       0.210897
#
#                                                    SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                                             0.001000
# SupportVectorRegressorWrapper__Quantile(normal)                                           1.000000
# SupportVectorRegressorWrapper__Quantile(uniform)                                          0.030700
# SupportVectorRegressorWrapper__PowerTransformer                                           0.437421
# SupportVectorRegressorWrapper__LogTransformer(ln)                                         0.393897
#
#                                                    SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                                              0.843526
# SupportVectorRegressorWrapper__Quantile(normal)                                            0.030700
# SupportVectorRegressorWrapper__Quantile(uniform)                                           1.000000
# SupportVectorRegressorWrapper__PowerTransformer                                            0.723137
# SupportVectorRegressorWrapper__LogTransformer(ln)                                          0.763265
#
#                                                    SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                                             0.182487
# SupportVectorRegressorWrapper__Quantile(normal)                                           0.437421
# SupportVectorRegressorWrapper__Quantile(uniform)                                          0.723137
# SupportVectorRegressorWrapper__PowerTransformer                                           1.000000
# SupportVectorRegressorWrapper__LogTransformer(ln)                                         0.900000
#
#                                                    SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                                               0.210897
# SupportVectorRegressorWrapper__Quantile(normal)                                             0.393897
# SupportVectorRegressorWrapper__Quantile(uniform)                                            0.763265
# SupportVectorRegressorWrapper__PowerTransformer                                             0.900000
# SupportVectorRegressorWrapper__LogTransformer(ln)                                           1.000000
# sign diffs                                                    SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                                              False
# SupportVectorRegressorWrapper__Quantile(normal)                             True
# SupportVectorRegressorWrapper__Quantile(uniform)                           False
# SupportVectorRegressorWrapper__PowerTransformer                            False
# SupportVectorRegressorWrapper__LogTransformer(ln)                          False
#
#                                                    SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                                                 True
# SupportVectorRegressorWrapper__Quantile(normal)                                              False
# SupportVectorRegressorWrapper__Quantile(uniform)                                              True
# SupportVectorRegressorWrapper__PowerTransformer                                              False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            False
#
#                                                    SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                                                 False
# SupportVectorRegressorWrapper__Quantile(normal)                                                True
# SupportVectorRegressorWrapper__Quantile(uniform)                                              False
# SupportVectorRegressorWrapper__PowerTransformer                                               False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                             False
#
#                                                    SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                                                False
# SupportVectorRegressorWrapper__Quantile(normal)                                              False
# SupportVectorRegressorWrapper__Quantile(uniform)                                             False
# SupportVectorRegressorWrapper__PowerTransformer                                              False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                            False
#
#                                                    SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                                                  False
# SupportVectorRegressorWrapper__Quantile(normal)                                                False
# SupportVectorRegressorWrapper__Quantile(uniform)                                               False
# SupportVectorRegressorWrapper__PowerTransformer                                                False
# SupportVectorRegressorWrapper__LogTransformer(ln)                                              False
# ##############################################
# Number of compared methods: 5
# Number of datasets: 10
# Bonferroni-Dunn-corrected alpha value: 0.0125
# p values:                                 SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                            1.0
#
#                                SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                         0.000101
#
#                                SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                          0.322199
#
#                                SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                         0.028377
#
#                                SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                           0.033895
# sign diffs                                SupportVectorRegressorWrapper  \
# SupportVectorRegressorWrapper                          False
#
#                                SupportVectorRegressorWrapper__Quantile(normal)  \
# SupportVectorRegressorWrapper                                             True
#
#                                SupportVectorRegressorWrapper__Quantile(uniform)  \
# SupportVectorRegressorWrapper                                             False
#
#                                SupportVectorRegressorWrapper__PowerTransformer  \
# SupportVectorRegressorWrapper                                            False
#
#                                SupportVectorRegressorWrapper__LogTransformer(ln)
# SupportVectorRegressorWrapper                                              False
# ##############################################
# average improvement compared with the first column:
#                                                     SupportVectorRegressorWrapper
# SupportVectorRegressorWrapper__Quantile(normal)                        23.266929
# SupportVectorRegressorWrapper__Quantile(uniform)                       12.257983
# SupportVectorRegressorWrapper__PowerTransformer                        -0.014015
# SupportVectorRegressorWrapper__LogTransformer(ln)                     -18.353372
